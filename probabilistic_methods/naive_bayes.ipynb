# %%
# !pip install pandas nltk scikit-learn
# Out:
# Requirement already satisfied: pandas in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: nltk in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.22.4 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: click in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: tqdm in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from nltk) (4.66.5)
# Requirement already satisfied: regex>=2021.8.3 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: joblib in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: six>=1.5 in /home/leontxo/Documents/kaggle/NLP-sesion/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
from nltk.tag import pos_tag
from sklearn.preprocessing import FunctionTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
df = pd.read_csv('/workspaces/NLP-sesion/IMDBDataset.csv', nrows=3500)

# %%
def data_cleaning(text_list): 
    #Stop words will be removed from the text
    stopwords_rem = False
    #It creates a list of strings with the english stopwords
    stopwords_en=stopwords.words('english')
    #It takes the base of the word provided.
    lemmatizer=WordNetLemmatizer()
    #It divides text into words.
    tokenizer=TweetTokenizer()
    reconstructed_list=[]
    for each_text in text_list: 
        lemmatized_tokens=[]
        #Converts to lowercase and then tokenizes
        tokens=tokenizer.tokenize(each_text.lower())
        #Each word is tagged with it's type, verb, noun,... It returns a tuple with the word and it's type
        pos_tags=pos_tag(tokens)
        for each_token, tag in pos_tags: 
            if tag.startswith('NN'): 
                pos='n'
            elif tag.startswith('VB'): 
                pos='v'
            else: 
                pos='a'
            lemmatized_token=lemmatizer.lemmatize(each_token, pos)
            if stopwords_rem: # False 
                if lemmatized_token not in stopwords_en: 
                    lemmatized_tokens.append(lemmatized_token)
            else: 
                lemmatized_tokens.append(lemmatized_token)
        reconstructed_list.append(' '.join(lemmatized_tokens))
    return(reconstructed_list)

# %%
#This is a pipeline that cleans the text with the function data_cleaning and then it creates a Term Frequency-Inverse Document Frequency matrix
# This matrix holds in its rows each text string and each column is a feature (unigram or bigram)
estimators = [('cleaner', FunctionTransformer(data_cleaning)),  ('vectorizer', TfidfVectorizer(max_features=100000, ngram_range=(1, 2)))]
preprocessing_pipeline=Pipeline(estimators)

# %%
X = df['review']
y=df['sentiment']
X_train, X_test, y_train, y_test=train_test_split(X, y)

# %%
X_train_transformed=preprocessing_pipeline.fit_transform(X_train)

# %%
X_train_dense = X_train_transformed.toarray()

# %%
feature_names = preprocessing_pipeline.named_steps['vectorizer'].get_feature_names_out()
print(feature_names)
# Out:
# ['00' '00 and' '00 be' ... 'zulu' 'æon' 'être']

# %%
print(feature_names[0], X_train_dense[0, 0])
# Out:
# 00 0.0

# %%
print(X_train_transformed[0,0:4])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (1, 4)>

# %%
nb=MultinomialNB()
nb.fit(X_train_transformed, y_train)
# Out:
# MultinomialNB()

# %%
X_test_transformed=preprocessing_pipeline.transform(X_test)
y_pred = nb.predict(X_test_transformed)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 84.34%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.80      0.91      0.85       434
#     positive       0.90      0.78      0.83       441
#
#     accuracy                           0.84       875
#    macro avg       0.85      0.84      0.84       875
# weighted avg       0.85      0.84      0.84       875

# %%
test_sentence = ["It was not painful to watch, actually i thought it was an ok movie"]
test_sentence_tfidf  = preprocessing_pipeline.transform(test_sentence)
predictions = nb.predict(test_sentence_tfidf)

print(predictions)
# Out:
# ['negative']
